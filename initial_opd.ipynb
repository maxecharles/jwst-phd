# %%
import webbpsf
import jax.numpy as np
import matplotlib.pyplot as plt

plt.rcParams['image.origin'] = 'lower'
# Out:
# **WARNING**: LOCAL JWST PRD VERSION PRDOPSSOC-059 CANNOT BE CHECKED AGAINST ONLINE VERSION

# %%
from optics import NIRISSOptics
from bases import generate_jwst_hexike_bases

Bases = generate_jwst_hexike_bases(nterms=10, AMI=True, AMI_type='full')
osys = NIRISSOptics(wf_npixels=Bases.npix, bases=Bases)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 from optics import NIRISSOptics
#       2 from bases import generate_jwst_hexike_bases
# ----> 4 Bases = generate_jwst_hexike_bases(nterms=10, AMI=True, AMI_type='full')
#       5 osys = NIRISSOptics(wf_npixels=Bases.npix, bases=Bases)
#
# File ~/Library/CloudStorage/OneDrive-TheUniversityofSydney(Students)/PyCharm/jwst/bases.py:141, in generate_jwst_hexike_bases(nterms, npix, AMI, AMI_type)
#     138     if AMI_type == "masked":
#     139         bases *= transmission
# --> 141 return HexikeBases(bases, transmission, pscale)
#
# File ~/miniconda3/envs/dLux/lib/python3.10/site-packages/equinox/_module.py:185, in _ModuleMeta.__call__(cls, *args, **kwargs)
#     182 def __call__(cls, *args, **kwargs):
#     183     # Defreeze it during __init__
#     184     initable_cls = _make_initable(cls, wraps=False)
# --> 185     self = super(_ModuleMeta, initable_cls).__call__(*args, **kwargs)
#     186     missing_names = {
#     187         field.name
#     188         for field in dataclasses.fields(cls)  # pyright: ignore
#     189         if field.init and field.name not in dir(self)
#     190     }
#     191     if len(missing_names):
#
# File ~/miniconda3/envs/dLux/lib/python3.10/site-packages/equinox/_better_abstract.py:280, in ABCMeta.__call__(cls, *args, **kwargs)
#     275     abstract_class_vars = set(cls.__abstractclassvars__)  # pyright: ignore
#     276     raise TypeError(
#     277         f"Can't instantiate abstract class {cls.__name__} with abstract class "
#     278         f"attributes {abstract_class_vars}"
#     279     )
# --> 280 self = super().__call__(*args, **kwargs)
#     281 abstract_vars = set()
#     282 for name in cls.__abstractvars__:  # pyright: ignore
#     283     # Deliberately not doing `if name in self.__dict__` to allow for use of
#     284     # properties (which are actually class attributes) to override abstract
#     285     # instance variables.
#
# TypeError: Can't instantiate abstract class HexikeBases with abstract method __call__

# %%
osys
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 osys.pupil.basis_opd
#
# NameError: name 'osys' is not defined

# %%
Bases
# Out:
# HexikeBases(
#   pixel_scale=0.0064486953125,
#   npix=1024,
#   nterms=10,
#   bases=f32[7,10,1024,1024],
#   transmission=f32[1024,1024]
# )

# %%
webbpsfobj = webbpsf.NIRISS()
webbpsfobj.pupil_mask = "MASK_NRM"
niriss_osys = webbpsfobj.get_optical_system()

opd = 1e9 * np.flip(niriss_osys.planes[0].opd)
transmission = niriss_osys.planes[3].amplitude

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
ax[0].imshow(opd, cmap="coolwarm")
ax[1].imshow(transmission * opd, cmap="coolwarm")
plt.show()

# %%
from bases import jwst_hexike_bases
bases, mask, pscale = jwst_hexike_bases(nterms=10, AMI=True, AMI_type='shifted')

# %%
from utils import plot_bases
plot_bases(bases, pscale, edges=True)

# %% [markdown]
# # Making fake aberrations

# %%
import jax.random as jr
fake_coeffs = jr.normal(jr.PRNGKey(0), bases.shape[:2])
print(f'Fake coeffs shape: {fake_coeffs.shape}')
# Out:
# Fake coeffs shape: (7, 10)

# %%
from bases import scale_bases
from utils import plot_opd

fake_opd = scale_bases(fake_coeffs, bases)
plot_opd(fake_opd, pscale, mask=mask)

# %%
def loss_fn(flat_coeffs, bases, data):
    coeffs = flat_coeffs.reshape(*bases.shape[:2])
    opd = scale_bases(coeffs, bases)
    
    return np.sum((opd - data)**2)

initial_coeffs = jr.normal(jr.PRNGKey(1), bases.shape[:2])

# %%
# %%time
loss = loss_fn(initial_coeffs, bases, fake_opd) # Compile
print("Initial Loss: {}".format(loss))
# Out:
# Initial Loss: 2835318.25
# CPU times: user 270 ms, sys: 28.1 ms, total: 298 ms
# Wall time: 76.4 ms

# %%
import zodiax as zdx
import optax
optim, opt_state = zdx.get_optimiser(scale_bases, param, optax.adam(1e-8))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 import zodiax as zdx
#       2 import optax
# ----> 3 optim, opt_state = zdx.get_optimiser(scale_bases, param, optax.adam(1e-8))
#
# NameError: name 'param' is not defined

# %%
opt_opd = scale_bases(result.x.reshape(*bases.shape[:2]), bases)
plot_opd(1e9 * opt_opd, pscale, mask=mask)

# %%
np.allclose(opt_opd, fake_opd)

# %%
plt.imshow(1e9*(opt_opd - fake_opd), cmap="coolwarm")
plt.colorbar()

# %%
import dLux as dl
