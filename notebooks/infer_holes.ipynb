# %%
import dLuxWebbpsf as dlW
import matplotlib.pyplot as plt
import dLux as dl

# %%
tel = dlW.NIRISS(
    filter='F430M',
    pupil_mask="MASK_NRM",
)

# %%
plt.imshow(tel.model())

# %%
ap = dl.RegPolyAperture(6, rmax=0.82)
